# %%
import pandas as pd


# read file
df = pd.read_csv('./FatalitiesMarch2018.csv')
df.head()
# Out:
#    Crash ID State  Month  Year  Dayweek   Time        Crash_Type  \
# 0  20181001   NSW  March  2018  Tuesday   7:18  Multiple vehicle
# 1  20181005   NSW  March  2018   Monday  18:25  Multiple vehicle
# 2  20181007   NSW  March  2018   Friday   8:00        Pedestrian
# 3  20181012   NSW  March  2018   Friday  16:05  Multiple vehicle
# 4  20181016   NSW  March  2018   Sunday   1:45    Single vehicle
#
#   Bus_Involvement Rigid_Truck_Involvement Articulated_Truck_Involvement   \
# 0              No                     Yes                             No
# 1              No                      No                             No
# 2              No                      No                             No
# 3              No                     Yes                             No
# 4              No                      No                             No
#
#    Speed_Limit                                Road_User  Gender  Age
# ...

# %%
# group by year
df_categorized = df.groupby('Year')
